# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/aditi-avni/ML-FlyRank/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# I am choosing the freestyle lane because I want to understand how a machine learning model learns patterns from data and uses those patterns to make decisions. Through this internship, I want to learn how the model identifies which web pages should be reviewed for refresh by analyzing different features instead of relying on manually written rules. This will help me build a strong foundation in machine learning before exploring more specialized topics.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# - if I understand how the model is working I can make decisions like which feature to use and should i change the dataset and all those queries can be answered.
# - the person using this will be me.
# -  a wrong decision can make me trust an unreliable model and lead to making of poor decisions based on its predictions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# The dataset contains 30,000 pages and 44 different features, which gives enough information to study how a machine learning model identifies patterns. Around 16,262 pages are labeled as declining, providing many examples for the model to learn from. These numbers make this dataset suitable for understanding how machine learning learns from real-world data.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
# - Through this project, I want to understand how a machine learning model learns patterns from data and which features it considers important while making predictions.
# - I can only make observations based on the dataset and use the model as a decision-support tool.
# - I cannot claim that any feature directly causes a page to decline or that I have understood or predicted Google's ranking algorithm.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
